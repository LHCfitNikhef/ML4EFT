# %%
import pyhepmc

# pyhepmc.open can read most HepMC formats using auto-detection
with pyhepmc.open("/data/theorie/pherbsch/MG5_aMC_v3_4_1/small_shower_test/Events/run_01/tag_1_pythia8_events.hepmc") as f:
    event = f.read()

event #zoom in a lot to read what is happening
# Out:
# GenEvent(momentum_unit=1, length_unit=0, event_number=0, particles=[GenParticle(FourVector(0, 0, 6.5e+03, 6.5e+03), mass=0.93827, pid=2212, status=4), GenParticle(FourVector(-0.742, -2.36, 1.46e+03, 1.46e+03), mass=0, pid=21, status=61), GenParticle(FourVector(-2.1, 1.25, 475, 475), mass=0, pid=21, status=61), GenParticle(FourVector(-1.4, -0.293, 3.47, 3.75), mass=0, pid=21, status=61), GenParticle(FourVector(0.102, -1.45, 246, 246), mass=0, pid=21, status=61), GenParticle(FourVector(-0.205, 2.47, 43, 43.1), mass=0, pid=2, status=61), GenParticle(FourVector(0.861, 1.34, 1.97, 2.53), mass=0, pid=21, status=61), GenParticle(FourVector(-1.33, 3.32, 1.21e+03, 1.21e+03), mass=0, pid=21, status=61), GenParticle(FourVector(-0.0585, -0.929, 108, 108), mass=0, pid=2, status=61), GenParticle(FourVector(2.04, -1.54, 39.5, 39.5), mass=0, pid=21, status=61), GenParticle(FourVector(0.721, -2.01, 76.9, 76.9), mass=0, pid=21, status=61), GenParticle(FourVector(1.7, -0.464, 805, 805), mass=0, pid=21,
# ...
