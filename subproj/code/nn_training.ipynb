# %%
#importing stuff
import wget
import tarfile
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
import json

import ml4eft.core.classifier as classifier
import ml4eft.analyse.analyse as analyse
import ml4eft.plotting.features as features

rc('text', usetex=False)
rc('font', **{'family': 'DejaVu Sans', 'size': 22})
# Out:
# lhapdf not found: exact models will not be available

# %%
#defining functions for downloading remote files
def file_downloader(url, download_dir='./downloads'):

    if not os.path.exists(download_dir):
        os.mkdir(download_dir)
    file = wget.download(url, out=download_dir)
    return file

def untar(path_to_tar, destination='./downloads'):

    with tarfile.open(path_to_tar) as f:
        f.extractall(destination)

download_dir = './downloads'

# %%
#loading the training data
training_data_url = 'https://dl.dropboxusercontent.com/s/z16fz2ggbn244pl/training_data.tar.gz?dl=0'
training_data = file_downloader(training_data_url);
data_train_loc = training_data.split('.tar')[0]

untar(training_data);

# %%
# load eft events
coeff = ["ctGRe", "ctj8"]
events_eft = []
for c in coeff:
    path_to_events = os.path.join(data_train_loc, 'tt_{}_{}/events_0.pkl.gz'.format(c, c))
    events, xsec = analyse.Analyse.load_events(path_to_events)
    events_eft.append(events)

# load sm events
events_sm, xsec_sm = analyse.Analyse.load_events(os.path.join(download_dir, 'training_data/tt_sm/events_0.pkl.gz'))

# %%
#loading the runcard
path_to_runcard = 'https://dl.dropboxusercontent.com/s/v4ulo6icveh63fw/run_card_tt_llvlvlbb.json?dl=0'
runcard = file_downloader(path_to_runcard)

# %%
#open the runcard to see what the options are.
with open(runcard) as json_runcard:
    json_runcard_loaded = json.load(json_runcard)

json_runcard_loaded
# Out:
# {'process_id': 'tt',
#  'epochs': 2000,
#  'lr': 0.0001,
#  'n_batches': 50,
#  'output_size': 1,
#  'hidden_sizes': [100, 100, 100],
#  'n_dat': 100000,
#  'event_data': './downloads/training_data/',
#  'features': ['pt_l1',
#   'pt_l2',
#   'pt_l_leading',
#   'pt_l_trailing',
#   'eta_l1',
#   'eta_l2',
#   'eta_l_leading',
#   'eta_l_trailing',
#   'pt_ll',
#   'm_ll',
#   'DeltaPhi_ll',
#   'DeltaEta_ll',
#   'pt_b_leading',
#   'pt_b_trailing',
#   'eta_b_leading',
#   'eta_b_trailing',
#   'pt_bb',
#   'm_bb'],
#  'loss_type': 'CE',
#  'scaler_type': 'robust',
#  'patience': 200,
#  'val_ratio': 0.2,
#  'c_train': {'cQd8': 10,
#   'cQj18': 10,
#   'cQj38': 10,
#   'cQu8': 10,
#   'ctd8': 10,
#   'ctGRe': -10,
#   'ctj8': 10,
#   'ctu8': 10}}

# %%
# to change the runcard I can do the following
json_runcard_loaded['epochs'] = 200
json_runcard_loaded['lr'] = 0.001
json_runcard_loaded['n_batches'] = 50
json_runcard_loaded['patience'] = 10 # needs to be bigger than number of epochs

# %%
with open(runcard, 'w') as runcard_updated:
    json.dump(json_runcard_loaded, runcard_updated)

# %%
#now lets train a few models in a row.

output_dir = './models'
c_name = ctu8

fitter = classifier.Fitter(json_path = runcard,
                        mc_run = 0,
                        c_name = c_name,
                        output_dir = output_dir,
                        print_log=True)
# Out:
# 2022-11-28 13:28:49,437 [INFO] All directories created, ready to load the data
# 2022-11-28 13:28:49,979 [INFO] Dataset loaded from ./downloads/training_data/tt_ctj8/events_0.pkl.gz
# 2022-11-28 13:28:49,991 [INFO] Dataset loaded from ./downloads/training_data/tt_sm/events_0.pkl.gz
# 2022-11-28 13:28:56,462 [INFO] Epoch 1, Training loss 43.8582569360733, Validation loss 43.8582569360733, Overfit counter = 0
# 2022-11-28 13:29:03,026 [INFO] Epoch 2, Training loss 43.8582569360733, Validation loss 43.8582569360733, Overfit counter = 0
# 2022-11-28 13:29:09,622 [INFO] Epoch 3, Training loss 43.8582569360733, Validation loss 43.8582569360733, Overfit counter = 0
# 2022-11-28 13:29:16,704 [INFO] Epoch 4, Training loss 43.8582569360733, Validation loss 43.8582569360733, Overfit counter = 0
# 2022-11-28 13:29:23,555 [INFO] Epoch 5, Training loss 43.8582569360733, Validation loss 43.8582569360733, Overfit counter = 0
# 2022-11-28 13:29:30,128 [INFO] Epoch 6, Training loss 43.8582569360733, Validation loss 43.8582569360733, Overfit counter = 0
# 2022-11-28 13:29:36,918 [INFO] Epoch 7, Training loss 43.8582569360733, Validation loss 43.8582569360733, Overfit counter = 0
# 2022-11-28 13:29:43,734 [INFO] Epoch 8, Training loss 43.8582569360733, Validation loss 43.8582569360733, Overfit counter = 0
# 2022-11-28 13:29:50,491 [INFO] Epoch 9, Training loss 43.8582569360733, Validation loss 43.8582569360733, Overfit counter = 0
# 2022-11-28 13:29:57,096 [INFO] Epoch 10, Training loss 43.8582569360733, Validation loss 43.8582569360733, Overfit counter = 0
# 2022-11-28 13:30:03,779 [INFO] Epoch 11, Training loss 43.8582569360733, Validation loss 43.8582569360733, Overfit counter = 0
# 2022-11-28 13:30:03,785 [INFO] Detected stagnant training, reset the weights
# 2022-11-28 13:30:10,938 [INFO] Epoch 12, Training loss 3.213600892573595, Validation loss 4.898515164852142, Overfit counter = 0
# 2022-11-28 13:30:18,050 [INFO] Epoch 13, Training loss 3.0807310454547405, Validation loss 3.0669365748763084, Overfit counter = 0
# 2022-11-28 13:30:24,888 [INFO] Epoch 14, Training loss 3.071529198437929, Validation loss 3.059379003942013, Overfit counter = 0
# 2022-11-28 13:30:32,125 [INFO] Epoch 15, Training loss 3.0649160109460354, Validation loss 3.049605168402195, Overfit counter = 0
# 2022-11-28 13:30:39,856 [INFO] Epoch 16, Training loss 3.0604557543992996, Validation loss 3.047724299132824, Overfit counter = 0
# 2022-11-28 13:30:47,057 [INFO] Epoch 17, Training loss 3.0564944110810757, Validation loss 3.0425823032855988, Overfit counter = 0
# 2022-11-28 13:30:53,771 [INFO] Epoch 18, Training loss 3.054191004484892, Validation loss 3.041946195065975, Overfit counter = 0
# 2022-11-28 13:31:00,575 [INFO] Epoch 19, Training loss 3.0522358119487762, Validation loss 3.040448624640703, Overfit counter = 0
# 2022-11-28 13:31:07,140 [INFO] Epoch 20, Training loss 3.0511437989771366, Validation loss 3.03961218893528, Overfit counter = 0
# 2022-11-28 13:31:14,081 [INFO] Epoch 21, Training loss 3.049206171184778, Validation loss 3.0398248434066772, Overfit counter = 0
# 2022-11-28 13:31:20,774 [INFO] Epoch 22, Training loss 3.0477834157645702, Validation loss 3.039015084505081, Overfit counter = 1
# 2022-11-28 13:31:27,540 [INFO] Epoch 23, Training loss 3.046317059546709, Validation loss 3.03759940341115, Overfit counter = 0
# 2022-11-28 13:31:34,079 [INFO] Epoch 24, Training loss 3.044990386813879, Validation loss 3.036854263395071, Overfit counter = 0
# 2022-11-28 13:31:41,092 [INFO] Epoch 25, Training loss 3.044286262243986, Validation loss 3.0371362268924713, Overfit counter = 0
# 2022-11-28 13:31:47,650 [INFO] Epoch 26, Training loss 3.043863222002983, Validation loss 3.0380510687828064, Overfit counter = 1
# 2022-11-28 13:31:54,302 [INFO] Epoch 27, Training loss 3.042228862643242, Validation loss 3.037175990641117, Overfit counter = 2
# 2022-11-28 13:32:01,260 [INFO] Epoch 28, Training loss 3.04132479429245, Validation loss 3.037428718060255, Overfit counter = 3
# 2022-11-28 13:32:08,154 [INFO] Epoch 29, Training loss 3.03995319083333, Validation loss 3.038036033511162, Overfit counter = 4
# 2022-11-28 13:32:14,990 [INFO] Epoch 30, Training loss 3.042865440249443, Validation loss 3.036429673433304, Overfit counter = 5
# 2022-11-28 13:32:21,674 [INFO] Epoch 31, Training loss 3.039428547024727, Validation loss 3.0381827242672443, Overfit counter = 0
# 2022-11-28 13:32:28,482 [INFO] Epoch 32, Training loss 3.0377038903534412, Validation loss 3.0368775464594364, Overfit counter = 1
# 2022-11-28 13:32:35,336 [INFO] Epoch 33, Training loss 3.0387205854058266, Validation loss 3.0399910658597946, Overfit counter = 2
# 2022-11-28 13:32:42,145 [INFO] Epoch 34, Training loss 3.037076484411955, Validation loss 3.037645637989044, Overfit counter = 3
# 2022-11-28 13:32:49,032 [INFO] Epoch 35, Training loss 3.0358079224824905, Validation loss 3.037289272993803, Overfit counter = 4
# 2022-11-28 13:32:55,755 [INFO] Epoch 36, Training loss 3.034923903644085, Validation loss 3.040227770805359, Overfit counter = 5
# 2022-11-28 13:33:02,670 [INFO] Epoch 37, Training loss 3.0345749221742153, Validation loss 3.04134713858366, Overfit counter = 6
# 2022-11-28 13:33:09,579 [INFO] Epoch 38, Training loss 3.0336712412536144, Validation loss 3.038151193410158, Overfit counter = 7
# 2022-11-28 13:33:16,552 [INFO] Epoch 39, Training loss 3.0314729511737823, Validation loss 3.037390325218439, Overfit counter = 8
# 2022-11-28 13:33:23,336 [INFO] Epoch 40, Training loss 3.033002234995365, Validation loss 3.039999447762966, Overfit counter = 9
# 2022-11-28 13:33:23,341 [INFO] Stopping point reached! Overfit counter = 10
# 2022-11-28 13:33:23,345 [INFO] Backwards stopping done
# 2022-11-28 13:33:23,346 [INFO] Finished training
# 2022-11-28 13:33:23,356 [INFO] All directories created, ready to load the data
# 2022-11-28 13:33:23,849 [INFO] Dataset loaded from ./downloads/training_data/tt_ctGRe/events_0.pkl.gz
# 2022-11-28 13:33:23,860 [INFO] Dataset loaded from ./downloads/training_data/tt_sm/events_0.pkl.gz
# 2022-11-28 13:33:31,069 [INFO] Epoch 1, Training loss 5.596282280981541, Validation loss 48.51847594976425, Overfit counter = 0
# 2022-11-28 13:33:38,217 [INFO] Epoch 2, Training loss 4.079815030097961, Validation loss 4.0896372720599174, Overfit counter = 0
# 2022-11-28 13:33:45,116 [INFO] Epoch 3, Training loss 4.061973236501217, Validation loss 4.06626383960247, Overfit counter = 0
# 2022-11-28 13:33:51,745 [INFO] Epoch 4, Training loss 4.0468964502215385, Validation loss 4.046999059617519, Overfit counter = 0
# 2022-11-28 13:33:59,002 [INFO] Epoch 5, Training loss 4.040086902678013, Validation loss 4.036120817065239, Overfit counter = 0
# 2022-11-28 13:34:06,009 [INFO] Epoch 6, Training loss 4.035474210977554, Validation loss 4.031494572758675, Overfit counter = 0
# 2022-11-28 13:34:12,697 [INFO] Epoch 7, Training loss 4.031590491533279, Validation loss 4.027997925877571, Overfit counter = 0
# 2022-11-28 13:34:19,333 [INFO] Epoch 8, Training loss 4.030154950916767, Validation loss 4.030044689774513, Overfit counter = 0
# 2022-11-28 13:34:26,085 [INFO] Epoch 9, Training loss 4.02800440788269, Validation loss 4.029206797480583, Overfit counter = 0
# 2022-11-28 13:34:32,850 [INFO] Epoch 10, Training loss 4.027290545403957, Validation loss 4.029115557670593, Overfit counter = 0
# 2022-11-28 13:34:39,594 [INFO] Epoch 11, Training loss 4.026315905153751, Validation loss 4.027701877057552, Overfit counter = 0
# 2022-11-28 13:34:46,404 [INFO] Epoch 12, Training loss 4.026049047708511, Validation loss 4.026440992951393, Overfit counter = 0
# 2022-11-28 13:34:52,917 [INFO] Epoch 13, Training loss 4.024706944823265, Validation loss 4.02178780734539, Overfit counter = 0
# 2022-11-28 13:34:59,501 [INFO] Epoch 14, Training loss 4.022814430296421, Validation loss 4.026205189526081, Overfit counter = 0
# 2022-11-28 13:35:05,856 [INFO] Epoch 15, Training loss 4.021729484200478, Validation loss 4.02662443369627, Overfit counter = 0
# 2022-11-28 13:35:11,961 [INFO] Epoch 16, Training loss 4.021117195487022, Validation loss 4.025194436311722, Overfit counter = 0
# 2022-11-28 13:35:18,170 [INFO] Epoch 17, Training loss 4.020214162766933, Validation loss 4.025238290429115, Overfit counter = 0
# 2022-11-28 13:35:24,498 [INFO] Epoch 18, Training loss 4.019597813487053, Validation loss 4.028509512543678, Overfit counter = 0
# 2022-11-28 13:35:31,218 [INFO] Epoch 19, Training loss 4.018531769514084, Validation loss 4.024358652532101, Overfit counter = 0
# 2022-11-28 13:35:38,124 [INFO] Epoch 20, Training loss 4.017501056194305, Validation loss 4.024629652500153, Overfit counter = 0
# 2022-11-28 13:35:44,876 [INFO] Epoch 21, Training loss 4.01728979498148, Validation loss 4.028344176709652, Overfit counter = 0
# 2022-11-28 13:35:52,033 [INFO] Epoch 22, Training loss 4.015964224934578, Validation loss 4.028612926602364, Overfit counter = 1
# 2022-11-28 13:35:59,068 [INFO] Epoch 23, Training loss 4.015342585742474, Validation loss 4.027418702840805, Overfit counter = 2
# 2022-11-28 13:36:05,929 [INFO] Epoch 24, Training loss 4.014879904687405, Validation loss 4.03254672139883, Overfit counter = 3
# 2022-11-28 13:36:12,455 [INFO] Epoch 25, Training loss 4.015151381492615, Validation loss 4.02312994748354, Overfit counter = 4
# 2022-11-28 13:36:19,974 [INFO] Epoch 26, Training loss 4.013273060321808, Validation loss 4.022629588842392, Overfit counter = 5
# 2022-11-28 13:36:26,680 [INFO] Epoch 27, Training loss 4.013868749141693, Validation loss 4.0350131168961525, Overfit counter = 6
# 2022-11-28 13:36:33,993 [INFO] Epoch 28, Training loss 4.012437328696251, Validation loss 4.022947080433369, Overfit counter = 7
# 2022-11-28 13:36:42,180 [INFO] Epoch 29, Training loss 4.011275120079517, Validation loss 4.026443473994732, Overfit counter = 8
# 2022-11-28 13:36:48,941 [INFO] Epoch 30, Training loss 4.011618264019489, Validation loss 4.022805035114288, Overfit counter = 9
# 2022-11-28 13:36:48,947 [INFO] Stopping point reached! Overfit counter = 10
# 2022-11-28 13:36:48,950 [INFO] Backwards stopping done
# 2022-11-28 13:36:48,950 [INFO] Finished training
# 2022-11-28 13:36:48,967 [INFO] All directories created, ready to load the data
# 2022-11-28 13:36:49,439 [INFO] Dataset loaded from ./downloads/training_data/tt_ctj8_ctj8/events_0.pkl.gz
# 2022-11-28 13:36:49,451 [INFO] Dataset loaded from ./downloads/training_data/tt_sm/events_0.pkl.gz
# 2022-11-28 13:36:56,528 [INFO] Epoch 1, Training loss 9.474714435636997, Validation loss 144.56217217445374, Overfit counter = 0
# 2022-11-28 13:37:03,964 [INFO] Epoch 2, Training loss 5.724970482289791, Validation loss 5.90821348875761, Overfit counter = 0
# 2022-11-28 13:37:11,042 [INFO] Epoch 3, Training loss 5.549070701003075, Validation loss 5.6534736305475235, Overfit counter = 0
# 2022-11-28 13:37:18,062 [INFO] Epoch 4, Training loss 5.4605924263596535, Validation loss 5.566917613148689, Overfit counter = 0
# 2022-11-28 13:37:25,363 [INFO] Epoch 5, Training loss 5.482428774237633, Validation loss 5.5423401072621346, Overfit counter = 0
# 2022-11-28 13:37:33,754 [INFO] Epoch 6, Training loss 5.375517100095749, Validation loss 5.407081104815006, Overfit counter = 0
# 2022-11-28 13:37:40,670 [INFO] Epoch 7, Training loss 5.348527446389198, Validation loss 5.398343160748482, Overfit counter = 0
# 2022-11-28 13:37:47,517 [INFO] Epoch 8, Training loss 5.322662517428398, Validation loss 5.367162868380547, Overfit counter = 0
# 2022-11-28 13:37:54,878 [INFO] Epoch 9, Training loss 5.303068161010742, Validation loss 5.346986256539822, Overfit counter = 0
# 2022-11-28 13:38:01,883 [INFO] Epoch 10, Training loss 5.26214112341404, Validation loss 5.2934084087610245, Overfit counter = 0
# 2022-11-28 13:38:08,819 [INFO] Epoch 11, Training loss 5.278188206255436, Validation loss 5.310264386236668, Overfit counter = 0
# 2022-11-28 13:38:15,771 [INFO] Epoch 12, Training loss 5.322572514414787, Validation loss 5.3900279849767685, Overfit counter = 0
# 2022-11-28 13:38:22,715 [INFO] Epoch 13, Training loss 5.235490836203098, Validation loss 5.2584162801504135, Overfit counter = 0
# 2022-11-28 13:38:29,725 [INFO] Epoch 14, Training loss 5.207073353230953, Validation loss 5.359329953789711, Overfit counter = 0
# 2022-11-28 13:38:37,075 [INFO] Epoch 15, Training loss 5.186589308083057, Validation loss 5.228490844368935, Overfit counter = 0
# 2022-11-28 13:38:44,153 [INFO] Epoch 16, Training loss 5.177751801908016, Validation loss 5.203026585280895, Overfit counter = 0
# 2022-11-28 13:38:51,974 [INFO] Epoch 17, Training loss 5.173831924796104, Validation loss 5.198809511959553, Overfit counter = 0
# 2022-11-28 13:39:03,363 [INFO] Epoch 18, Training loss 5.157594859600067, Validation loss 5.20025297254324, Overfit counter = 0
# 2022-11-28 13:39:19,726 [INFO] Epoch 19, Training loss 5.147672154009342, Validation loss 5.1907589584589005, Overfit counter = 0
# 2022-11-28 13:39:35,770 [INFO] Epoch 20, Training loss 5.140858806669712, Validation loss 5.198511905968189, Overfit counter = 0
# 2022-11-28 13:39:50,210 [INFO] Epoch 21, Training loss 5.158984020352364, Validation loss 5.235221244394779, Overfit counter = 0
# 2022-11-28 13:39:59,485 [INFO] Epoch 22, Training loss 5.146756500005722, Validation loss 5.2011773660779, Overfit counter = 1
# 2022-11-28 13:40:09,887 [INFO] Epoch 23, Training loss 5.222307443618774, Validation loss 5.266322709619999, Overfit counter = 2
# 2022-11-28 13:40:20,387 [INFO] Epoch 24, Training loss 5.127324543893337, Validation loss 5.2016081511974335, Overfit counter = 3
# 2022-11-28 13:40:29,586 [INFO] Epoch 25, Training loss 5.111916534602642, Validation loss 5.176406174898148, Overfit counter = 4
# 2022-11-28 13:40:40,271 [INFO] Epoch 26, Training loss 5.10533444583416, Validation loss 5.1730896309018135, Overfit counter = 0
# 2022-11-28 13:40:49,349 [INFO] Epoch 27, Training loss 5.10244157910347, Validation loss 5.172441966831684, Overfit counter = 0
# 2022-11-28 13:41:00,541 [INFO] Epoch 28, Training loss 5.109850205481052, Validation loss 5.170381285250187, Overfit counter = 0
# 2022-11-28 13:41:10,354 [INFO] Epoch 29, Training loss 5.096025474369526, Validation loss 5.219776324927807, Overfit counter = 0
# 2022-11-28 13:41:20,039 [INFO] Epoch 30, Training loss 5.095961630344391, Validation loss 5.234682187438011, Overfit counter = 1
# 2022-11-28 13:41:28,735 [INFO] Epoch 31, Training loss 5.084427542984486, Validation loss 5.166095279157162, Overfit counter = 2
# 2022-11-28 13:41:36,759 [INFO] Epoch 32, Training loss 5.0840218141674995, Validation loss 5.272961743175983, Overfit counter = 0
# 2022-11-28 13:41:44,982 [INFO] Epoch 33, Training loss 5.108127035200596, Validation loss 5.2114846259355545, Overfit counter = 1
# 2022-11-28 13:41:53,352 [INFO] Epoch 34, Training loss 5.071326307952404, Validation loss 5.189506500959396, Overfit counter = 2
# 2022-11-28 13:42:01,665 [INFO] Epoch 35, Training loss 5.075147032737732, Validation loss 5.230847597122192, Overfit counter = 3
# 2022-11-28 13:42:09,858 [INFO] Epoch 36, Training loss 5.089041568338871, Validation loss 5.201439946889877, Overfit counter = 4
# 2022-11-28 13:42:16,369 [INFO] Epoch 37, Training loss 5.110971599817276, Validation loss 5.224971175193787, Overfit counter = 5
# 2022-11-28 13:42:22,623 [INFO] Epoch 38, Training loss 5.088262155652046, Validation loss 5.337720975279808, Overfit counter = 6
# 2022-11-28 13:42:28,935 [INFO] Epoch 39, Training loss 5.063281551003456, Validation loss 5.187376834452152, Overfit counter = 7
# 2022-11-28 13:42:35,194 [INFO] Epoch 40, Training loss 5.062525428831577, Validation loss 5.175126880407333, Overfit counter = 8
# 2022-11-28 13:42:41,768 [INFO] Epoch 41, Training loss 5.057817697525024, Validation loss 5.1988033428788185, Overfit counter = 9
# 2022-11-28 13:42:41,774 [INFO] Stopping point reached! Overfit counter = 10
# 2022-11-28 13:42:41,777 [INFO] Backwards stopping done
# 2022-11-28 13:42:41,778 [INFO] Finished training
# 2022-11-28 13:42:41,786 [INFO] All directories created, ready to load the data
# 2022-11-28 13:42:42,251 [INFO] Dataset loaded from ./downloads/training_data/tt_ctGRe_ctGRe/events_0.pkl.gz
# 2022-11-28 13:42:42,263 [INFO] Dataset loaded from ./downloads/training_data/tt_sm/events_0.pkl.gz
# 2022-11-28 13:42:49,049 [INFO] Epoch 1, Training loss 6.215768903493881, Validation loss 6.778317928314209, Overfit counter = 0
# 2022-11-28 13:42:55,770 [INFO] Epoch 2, Training loss 6.030410848557949, Validation loss 6.0350771471858025, Overfit counter = 0
# 2022-11-28 13:43:02,287 [INFO] Epoch 3, Training loss 6.0051663517951965, Validation loss 6.0005781054496765, Overfit counter = 0
# 2022-11-28 13:43:08,870 [INFO] Epoch 4, Training loss 5.988708719611168, Validation loss 5.986499086022377, Overfit counter = 0
# 2022-11-28 13:43:15,103 [INFO] Epoch 5, Training loss 5.976898558437824, Validation loss 5.973095893859863, Overfit counter = 0
# 2022-11-28 13:43:21,746 [INFO] Epoch 6, Training loss 5.971078336238861, Validation loss 5.963513642549515, Overfit counter = 0
# 2022-11-28 13:43:28,205 [INFO] Epoch 7, Training loss 5.973692707717419, Validation loss 6.001413561403751, Overfit counter = 0
# 2022-11-28 13:43:35,154 [INFO] Epoch 8, Training loss 5.953654579818249, Validation loss 5.9568489119410515, Overfit counter = 0
# 2022-11-28 13:43:42,086 [INFO] Epoch 9, Training loss 5.9595701321959496, Validation loss 5.954798258841038, Overfit counter = 0
# 2022-11-28 13:43:48,461 [INFO] Epoch 10, Training loss 5.942870035767555, Validation loss 5.953055500984192, Overfit counter = 0
# 2022-11-28 13:43:55,147 [INFO] Epoch 11, Training loss 5.943908557295799, Validation loss 5.994634926319122, Overfit counter = 0
# 2022-11-28 13:44:01,952 [INFO] Epoch 12, Training loss 5.931073844432831, Validation loss 5.949707090854645, Overfit counter = 0
# 2022-11-28 13:44:08,523 [INFO] Epoch 13, Training loss 5.934288173913956, Validation loss 5.950612880289555, Overfit counter = 0
# 2022-11-28 13:44:15,277 [INFO] Epoch 14, Training loss 5.930131174623966, Validation loss 5.954895809292793, Overfit counter = 0
# 2022-11-28 13:44:22,190 [INFO] Epoch 15, Training loss 5.921209014952183, Validation loss 5.967637710273266, Overfit counter = 0
# 2022-11-28 13:44:28,963 [INFO] Epoch 16, Training loss 5.924813814461231, Validation loss 5.961793877184391, Overfit counter = 0
# 2022-11-28 13:44:35,231 [INFO] Epoch 17, Training loss 5.919595398008823, Validation loss 6.009918384253979, Overfit counter = 0
# 2022-11-28 13:44:41,851 [INFO] Epoch 18, Training loss 5.922767333686352, Validation loss 5.950421705842018, Overfit counter = 0
# 2022-11-28 13:44:48,317 [INFO] Epoch 19, Training loss 5.91357347369194, Validation loss 5.96090991050005, Overfit counter = 0
# 2022-11-28 13:44:55,144 [INFO] Epoch 20, Training loss 5.916495852172375, Validation loss 6.001277312636375, Overfit counter = 0
# 2022-11-28 13:45:01,774 [INFO] Epoch 21, Training loss 5.908912472426891, Validation loss 5.990676887333393, Overfit counter = 0
# 2022-11-28 13:45:08,614 [INFO] Epoch 22, Training loss 5.910766489803791, Validation loss 5.986517861485481, Overfit counter = 1
# 2022-11-28 13:45:15,652 [INFO] Epoch 23, Training loss 5.90831346064806, Validation loss 5.962028369307518, Overfit counter = 2
# 2022-11-28 13:45:23,064 [INFO] Epoch 24, Training loss 5.915395334362984, Validation loss 5.97244568169117, Overfit counter = 3
# 2022-11-28 13:45:29,713 [INFO] Epoch 25, Training loss 5.904746122658253, Validation loss 5.950959965586662, Overfit counter = 4
# 2022-11-28 13:45:36,725 [INFO] Epoch 26, Training loss 5.9075997695326805, Validation loss 5.962381489574909, Overfit counter = 5
# 2022-11-28 13:45:43,514 [INFO] Epoch 27, Training loss 5.902565971016884, Validation loss 5.959824234247208, Overfit counter = 6
# 2022-11-28 13:45:50,296 [INFO] Epoch 28, Training loss 5.8960117027163506, Validation loss 5.948714852333069, Overfit counter = 7
# 2022-11-28 13:45:56,791 [INFO] Epoch 29, Training loss 5.915539287030697, Validation loss 5.986143991351128, Overfit counter = 0
# 2022-11-28 13:46:03,168 [INFO] Epoch 30, Training loss 5.8968954756855965, Validation loss 6.048929877579212, Overfit counter = 1
# 2022-11-28 13:46:09,899 [INFO] Epoch 31, Training loss 5.888415701687336, Validation loss 5.9769928231835365, Overfit counter = 2
# 2022-11-28 13:46:16,306 [INFO] Epoch 32, Training loss 5.8932152315974236, Validation loss 6.019629545509815, Overfit counter = 3
# 2022-11-28 13:46:23,161 [INFO] Epoch 33, Training loss 5.891577959060669, Validation loss 5.9794125854969025, Overfit counter = 4
# 2022-11-28 13:46:30,225 [INFO] Epoch 34, Training loss 6.016497477889061, Validation loss 5.9717871099710464, Overfit counter = 5
# 2022-11-28 13:46:36,781 [INFO] Epoch 35, Training loss 5.9917953833937645, Validation loss 6.1474519073963165, Overfit counter = 6
# 2022-11-28 13:46:43,187 [INFO] Epoch 36, Training loss 5.9672824293375015, Validation loss 6.039037182927132, Overfit counter = 7
# 2022-11-28 13:46:49,705 [INFO] Epoch 37, Training loss 5.928875677287579, Validation loss 5.958542890846729, Overfit counter = 8
# 2022-11-28 13:46:56,395 [INFO] Epoch 38, Training loss 5.920576892793179, Validation loss 5.954611577093601, Overfit counter = 9
# 2022-11-28 13:46:56,400 [INFO] Stopping point reached! Overfit counter = 10
# 2022-11-28 13:46:56,403 [INFO] Backwards stopping done
# 2022-11-28 13:46:56,404 [INFO] Finished training
